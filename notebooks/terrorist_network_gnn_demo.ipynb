# %% [markdown]
# # Terrorist Network Disruption using Temporal GNN
#
# ## 📋 Core Research Framework
# - **Q1**: Which nodes, when removed, most effectively disrupt the network?
# - **Q2**: How will the network reconstruct after node removal?
# - **Q3**: How does the network adapt to disruption attempts?
#
#
# ## 🏗️ System Architecture
# - **1. Multi-Layer Temporal Network**
# - **2. Advanced Temporal GNN Model**
# - **3. Critical Node Detection**
# - **4. Temporal Resilience Predictor**
# - **5. Adversarial Robustness Analyzer**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/TGNN_v1/
# Out:
# /content/drive/MyDrive/TGNN_v1

# %% [markdown]
# ## 1. Setup and Installation

# %%
# Install required packages
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install torch-geometric
#!pip install torch-scatter torch-sparse -f https://data.pyg.org/whl/torch-2.0.0+cu118.html
# !pip install networkx matplotlib seaborn scipy numpy pandas tqdm
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Collecting torch-geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.13.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch-geometric) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (2025.11.12)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->torch-geometric) (4.15.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.7 MB/s eta 0:00:00
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.7.0
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# Check GPU availability
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
# Out:
# PyTorch version: 2.9.0+cu126
# CUDA available: True
# CUDA version: 12.6
# GPU: Tesla T4
# GPU Memory: 14.74 GB

# %% [markdown]
# ## 2. Upload Source Files

# %%
# Verify all files are uploaded
import os

required_files = [
    'advanced_tgnn.py',
    'terrorist_network_disruption.py',
    'terrorist_network_dataset.py',
    'training.py',
    'baselines.py',
    'statistical_analysis.py',
    'ablation_study.py',
    'main_experiment.py'
]

base_path = "./src"

print("Checking for required files:")
all_present = True
for file in required_files:
    file_path = os.path.join(base_path, file)
    file_exists = os.path.exists(file_path)
    mark = "✓" if file_exists else "✗"
    print(f"{mark} {file_path}")

    if not file_exists:
        all_present = False

if all_present:
    print("\n✓ All files present!")
else:
    print("\n✗ Some files are missing. Please upload them.")
# Out:
# Checking for required files:
# ✓ ./src/advanced_tgnn.py
# ✓ ./src/terrorist_network_disruption.py
# ✓ ./src/terrorist_network_dataset.py
# ✓ ./src/training.py
# ✓ ./src/baselines.py
# ✓ ./src/statistical_analysis.py
# ✓ ./src/ablation_study.py
# ✓ ./src/main_experiment.py
#
# ✓ All files present!

# %% [markdown]
# ## 3. Quick Demo Run (Fast Testing)
#
# Run with minimal networks for quick testing (5-10 minutes)

# %%
import sys
sys.path.append("./src")
from main_experiment import EnhancedExperiment, NetworkConfig

# Quick test configuration
network_config = NetworkConfig(
    initial_nodes=30,
    max_nodes=50,
    recruitment_rate=0.05,
    dropout_rate=0.02,
    physical_density=0.15,
    digital_density=0.35,
    financial_density=0.08,
    ideological_density=0.30,
    operational_density=0.06
)

model_config = {
    'num_node_features': 64,
    'num_edge_features': 32,
    'hidden_dim': 128
}

# Create experiment
experiment = EnhancedExperiment(
    config=network_config,
    model_config=model_config,
    output_dir='experiments/quick_test'
)

# Run quick test
experiment.run_complete_experiment(
    num_networks=3,      # Small for quick test
    num_timesteps=10,    # Fewer timesteps
    train_model=True,
    run_baselines=True,
    run_ablation=False   # Skip ablation for speed
)
# Out:
# ================================================================================
# TERRORIST NETWORK DISRUPTION - ENHANCED EXPERIMENT (PHASE 1)
# ================================================================================
#
# Configuration:
#   Networks: 3
#   Timesteps: 10
#   Device: cuda
#   Output: experiments/quick_test
#   Train Model: True
#   Run Baselines: True
#   Run Ablation: False
#
# ================================================================================
# PHASE 1: Network Generation
# ================================================================================
#
# Generating network 1/3...
#
# Generating terrorist network with 10 timesteps...
#   Generated timestep 5/10
#   Generated timestep 10/10
# ✓ Network generation complete!
#   Final size: 39 nodes
#   Leaders: 1
#   Operatives: 9
#   Supporters: 29
#
# Generating network 2/3...
#
# Generating terrorist network with 10 timesteps...
#   Generated timestep 5/10
#   Generated timestep 10/10
# ✓ Network generation complete!
#   Final size: 39 nodes
#   Leaders: 1
#   Operatives: 6
#   Supporters: 32
#
# Generating network 3/3...
#
# Generating terrorist network with 10 timesteps...
#   Generated timestep 5/10
#   Generated timestep 10/10
# ✓ Network generation complete!
#   Final size: 39 nodes
#   Leaders: 1
#   Operatives: 7
#   Supporters: 31
#
# ✓ Generated 3 networks
#
# Dataset Split:
#   Train: 1
#   Validation: 0
#   Test: 2
#
# ================================================================================
# PHASE 2: Model Training with Self-Supervised Learning
# ================================================================================
#
# Building Multi-Layer Temporal GNN...
# ✓ Model created with 7,121,856 parameters
#
# Training with self-supervised learning...
# Tasks:
#   - Temporal link prediction
#   - Contrastive learning
#   - Node reconstruction
#
# ================================================================================
# TRAINING TEMPORAL GNN
# ================================================================================
# Training networks: 1
# Validation networks: 0
# Epochs: 50
# Device: cuda
#
# Epoch 005/50 | Train Loss: 2.4470 | Val Loss: 0.0000 | Link: 1.3993 | Contrast: 2.0761 | Recon: 0.0323 | Time: 9.50s
# Epoch 010/50 | Train Loss: 2.3446 | Val Loss: 0.0000 | Link: 1.3852 | Contrast: 1.9096 | Recon: 0.0154 | Time: 10.01s
#
# Early stopping at epoch 11
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Best validation loss: 0.0000
#
# ================================================================================
# PHASE 3: Baseline Method Comparison
# ================================================================================
#
# Initializing baselines...
#   Adding Static GCN...
#   Adding Static GAT...
#   Adding Static GraphSAGE...
#   Adding Simple Temporal GNN...
#
# Evaluating all baselines on test networks...
#
#   Network 1/2...
# Evaluating random...
# Evaluating degree...
# Evaluating betweenness...
# Evaluating pagerank...
# Evaluating eigenvector...
# Evaluating graph_partition...
# Evaluating static_gcn...
# Evaluating static_gat...
# Evaluating static_graphsage...
# Evaluating simple_tgnn...
#
#   Network 2/2...
# Evaluating random...
# Evaluating degree...
# Evaluating betweenness...
# Evaluating pagerank...
# Evaluating eigenvector...
# Evaluating graph_partition...
# Evaluating static_gcn...
# Evaluating static_gat...
# Evaluating static_graphsage...
# Evaluating simple_tgnn...
#
#   Evaluating our method...
#
# ================================================================================
# BASELINE COMPARISON RESULTS
# ================================================================================
# Method                    Mean         Std          Min          Max
# --------------------------------------------------------------------------------
# static_gcn                0.5400       0.0321       0.5080       0.5721
# static_gat                0.5400       0.0321       0.5080       0.5721
# static_graphsage          0.5400       0.0321       0.5080       0.5721
# simple_tgnn               0.5400       0.0321       0.5080       0.5721
# degree                    0.5220       0.0549       0.4672       0.5769
# our_method                ★ 0.5213       0.0114       0.5099       0.5327
# betweenness               0.5135       0.0069       0.5066       0.5204
# graph_partition           0.5135       0.0069       0.5066       0.5204
# pagerank                  0.5000       0.0328       0.4672       0.5328
# eigenvector               0.4927       0.0330       0.4597       0.5257
# random                    0.3834       0.0205       0.3629       0.4039
# ================================================================================
#
# ================================================================================
# PHASE 4: Critical Node Detection (Q1)
# ================================================================================
#
# Research Question 1: Critical Node Detection
# ================================================================================
#
# Evaluating network 1/2...
#
# Evaluating network 2/2...
#
# ================================================================================
# Q1 Results Summary:
# ================================================================================
#
# OUR_GNN:
#   Mean Disruption: 0.4893 (±0.0098)
#   Min: 0.4795, Max: 0.4992
#
# DEGREE:
#   Mean Disruption: 0.5400 (±0.0321)
#   Min: 0.5080, Max: 0.5721
#
# BETWEENNESS:
#   Mean Disruption: 0.5135 (±0.0069)
#   Min: 0.5066, Max: 0.5204
#
# PAGERANK:
#   Mean Disruption: 0.5000 (±0.0328)
#   Min: 0.4672, Max: 0.5328
#
# ENSEMBLE:
#   Mean Disruption: 0.5213 (±0.0114)
#   Min: 0.5099, Max: 0.5327
#
# ================================================================================
# PHASE 5: Temporal Resilience Prediction (Q2)
# ================================================================================
#
# Research Question 2: Temporal Resilience Prediction
# ================================================================================
#
# Analyzing network 1/2...
#   Resilience Score: 1.000
#
# Analyzing network 2/2...
#   Resilience Score: 1.000
#
# ✓ Average Resilience: 1.000
#
# ================================================================================
# PHASE 6: Adversarial Robustness (Q3)
# ================================================================================
#
# Research Question 3: Adversarial Robustness
# ================================================================================
#
# Network 1/2...
#   Testing decentralize adaptation...
#   Testing recruit adaptation...
#   Testing go_dark adaptation...
#   Testing subdivide adaptation...
#
# Network 2/2...
#   Testing decentralize adaptation...
#   Testing recruit adaptation...
#   Testing go_dark adaptation...
#   Testing subdivide adaptation...
#
# ================================================================================
# Q3 Results Summary:
# ================================================================================
#
# DECENTRALIZE:
#   Average Disruption: 0.164
#   Average Recovery Rate: 0.935
#
# RECRUIT:
#   Average Disruption: 0.172
#   Average Recovery Rate: 0.935
#
# GO_DARK:
#   Average Disruption: 0.164
#   Average Recovery Rate: 0.654
#
# SUBDIVIDE:
#   Average Disruption: 0.161
#   Average Recovery Rate: 0.717
#
# ================================================================================
# PHASE 7: Statistical Significance Testing
# ================================================================================
#
# Performing statistical analysis...
#
# ================================================================================
# STATISTICAL SUMMARY
# ================================================================================
# Method               Mean         Std          Median       95% CI
# --------------------------------------------------------------------------------
# degree               0.5400       0.0454       0.5400       [0.1325, 0.9476]
# ensemble             0.5213       0.0161       0.5213       [0.3765, 0.6661]
# betweenness          0.5135       0.0097       0.5135       [0.4260, 0.6009]
# pagerank             0.5000       0.0464       0.5000       [0.0827, 0.9172]
# our_gnn              0.4893       0.0139       0.4893       [0.3642, 0.6145]
# ================================================================================
#
# Pairwise Statistical Comparisons:
#
# our_gnn:
#   No significant difference (p=0.4398)
#   Effect size (Cohen's d): 0.855
#
# betweenness:
#   No significant difference (p=0.4831)
#   Effect size (Cohen's d): 0.746
#
# pagerank:
#   Method A significantly outperforms Method B (p=0.0121)
#   Effect size (Cohen's d): 37.276
#   ✓ Significant after Bonferroni correction
#
# ensemble:
#   No significant difference (p=0.5313)
#   Effect size (Cohen's d): 0.641
#
# ================================================================================
# BASELINE COMPARISON STATISTICS
# ================================================================================
#
# ================================================================================
# STATISTICAL SUMMARY
# ================================================================================
# Method               Mean         Std          Median       95% CI
# --------------------------------------------------------------------------------
# static_gcn           0.5400       0.0454       0.5400       [0.1325, 0.9476]
# static_gat           0.5400       0.0454       0.5400       [0.1325, 0.9476]
# static_graphsage     0.5400       0.0454       0.5400       [0.1325, 0.9476]
# simple_tgnn          0.5400       0.0454       0.5400       [0.1325, 0.9476]
# degree               0.5220       0.0776       0.5220       [-0.1751, 1.2191]
# our_method           0.5213       0.0161       0.5213       [0.3765, 0.6661]
# betweenness          0.5135       0.0097       0.5135       [0.4260, 0.6009]
# graph_partition      0.5135       0.0097       0.5135       [0.4260, 0.6009]
# pagerank             0.5000       0.0464       0.5000       [0.0827, 0.9172]
# eigenvector          0.4927       0.0467       0.4927       [0.0731, 0.9123]
# random               0.3834       0.0290       0.3834       [0.1230, 0.6438]
# ================================================================================
#
# Our Method vs Baselines:
#
# random:
#   Method A significantly outperforms Method B (p=0.0419)
#   Effect size: 10.719
#
# degree:
#   No significant difference (p=0.9896)
#   Effect size: -0.012
#
# betweenness:
#   No significant difference (p=0.3328)
#   Effect size: 1.227
#
# pagerank:
#   No significant difference (p=0.5019)
#   Effect size: 0.703
#
# eigenvector:
#   No significant difference (p=0.4121)
#   Effect size: 0.935
#
# graph_partition:
#   No significant difference (p=0.3328)
#   Effect size: 1.227
#
# static_gcn:
#   No significant difference (p=0.5313)
#   Effect size: -0.641
#
# static_gat:
#   No significant difference (p=0.5313)
#   Effect size: -0.641
#
# static_graphsage:
#   No significant difference (p=0.5313)
#   Effect size: -0.641
#
# simple_tgnn:
#   No significant difference (p=0.5313)
#   Effect size: -0.641
#
# ================================================================================
# PHASE 9: Results Analysis and Visualization
# ================================================================================
#
# Saving results...
# ✓ Results saved to: experiments/quick_test/results_phase1.json
#
# Creating visualizations...
# ✓ Visualizations saved to: experiments/quick_test/figures
#
# ================================================================================
# EXPERIMENT COMPLETE!
# ================================================================================
#
# Results saved to: experiments/quick_test
#
# Key Achievements:
#   ✓ Model trained with self-supervised learning
#   ✓ Comprehensive baseline comparisons
#   ✓ Statistical significance established
#   ✓ Component contributions quantified

# %% [markdown]
# ## 4. Production Run (Full Experiment)
#
# Run with full settings for paper-quality results (30-60 minutes)

# %%
import sys
sys.path.append("./src")

# Production configuration
network_config = NetworkConfig(
    initial_nodes=50,
    max_nodes=80,
    recruitment_rate=0.05,
    dropout_rate=0.02,
    physical_density=0.15,
    digital_density=0.35,
    financial_density=0.08,
    ideological_density=0.30,
    operational_density=0.06
)

model_config = {
    'num_node_features': 64,
    'num_edge_features': 32,
    'hidden_dim': 128
}

# Create experiment
experiment = EnhancedExperiment(
    config=network_config,
    model_config=model_config,
    output_dir='experiments/phase1_full'
)

# Run full experiment
experiment.run_complete_experiment(
    num_networks=10,     # More networks for statistical power
    num_timesteps=20,    # Full temporal dynamics
    train_model=True,    # Train with self-supervised learning
    run_baselines=True,  # Compare with all baselines
    run_ablation=True    # Ablation study
)
# Out:
# ================================================================================
# TERRORIST NETWORK DISRUPTION - ENHANCED EXPERIMENT (PHASE 1)
# ================================================================================
#
# Configuration:
#   Networks: 10
#   Timesteps: 20
#   Device: cuda
#   Output: experiments/phase1_full
#   Train Model: True
#   Run Baselines: True
#   Run Ablation: True
#
# ================================================================================
# PHASE 1: Network Generation
# ================================================================================
#
# Generating network 1/10...
#
# Generating terrorist network with 20 timesteps...
#   Generated timestep 5/20
#   Generated timestep 10/20
#   Generated timestep 15/20
#   Generated timestep 20/20
# ✓ Network generation complete!
#   Final size: 77 nodes
#   Leaders: 2
#   Operatives: 14
#   Supporters: 61
#
# Generating network 2/10...
#
# Generating terrorist network with 20 timesteps...
#   Generated timestep 5/20
#   Generated timestep 10/20
#   Generated timestep 15/20
#   Generated timestep 20/20
# ✓ Network generation complete!
#   Final size: 77 nodes
#   Leaders: 2
#   Operatives: 18
#   Supporters: 57
#
# Generating network 3/10...
#
# Generating terrorist network with 20 timesteps...
#   Generated timestep 5/20
#   Generated timestep 10/20
#   Generated timestep 15/20
#   Generated timestep 20/20
# ✓ Network generation complete!
#   Final size: 77 nodes
#   Leaders: 2
#   Operatives: 13
#   Supporters: 62
#
# Generating network 4/10...
#
# Generating terrorist network with 20 timesteps...
#   Generated timestep 5/20
#   Generated timestep 10/20
#   Generated timestep 15/20
#   Generated timestep 20/20
# ✓ Network generation complete!
#   Final size: 77 nodes
#   Leaders: 2
#   Operatives: 13
#   Supporters: 62
#
# Generating network 5/10...
#
# Generating terrorist network with 20 timesteps...
#   Generated timestep 5/20
#   Generated timestep 10/20
#   Generated timestep 15/20
#   Generated timestep 20/20
# ✓ Network generation complete!
#   Final size: 77 nodes
#   Leaders: 1
#   Operatives: 12
#   Supporters: 64
#
# Generating network 6/10...
#
# Generating terrorist network with 20 timesteps...
#   Generated timestep 5/20
#   Generated timestep 10/20
#   Generated timestep 15/20
#   Generated timestep 20/20
# ✓ Network generation complete!
#   Final size: 77 nodes
#   Leaders: 2
#   Operatives: 8
#   Supporters: 67
#
# Generating network 7/10...
#
# Generating terrorist network with 20 timesteps...
#   Generated timestep 5/20
#   Generated timestep 10/20
#   Generated timestep 15/20
#   Generated timestep 20/20
# ✓ Network generation complete!
#   Final size: 77 nodes
#   Leaders: 2
#   Operatives: 13
#   Supporters: 62
#
# Generating network 8/10...
#
# Generating terrorist network with 20 timesteps...
#   Generated timestep 5/20
#   Generated timestep 10/20
#   Generated timestep 15/20
#   Generated timestep 20/20
# ✓ Network generation complete!
#   Final size: 77 nodes
#   Leaders: 2
#   Operatives: 13
#   Supporters: 62
#
# Generating network 9/10...
#
# Generating terrorist network with 20 timesteps...
#   Generated timestep 5/20
#   Generated timestep 10/20
#   Generated timestep 15/20
#   Generated timestep 20/20
# ✓ Network generation complete!
#   Final size: 77 nodes
#   Leaders: 2
#   Operatives: 14
#   Supporters: 61
#
# Generating network 10/10...
#
# Generating terrorist network with 20 timesteps...
#   Generated timestep 5/20
#   Generated timestep 10/20
#   Generated timestep 15/20
#   Generated timestep 20/20
# ✓ Network generation complete!
#   Final size: 77 nodes
#   Leaders: 2
#   Operatives: 15
#   Supporters: 60
#
# ✓ Generated 10 networks
#
# Dataset Split:
#   Train: 6
#   Validation: 2
#   Test: 2
#
# ================================================================================
# PHASE 2: Model Training with Self-Supervised Learning
# ================================================================================
#
# Building Multi-Layer Temporal GNN...
# ✓ Model created with 7,121,856 parameters
#
# Training with self-supervised learning...
# Tasks:
#   - Temporal link prediction
#   - Contrastive learning
#   - Node reconstruction
#
# ================================================================================
# TRAINING TEMPORAL GNN
# ================================================================================
# Training networks: 6
# Validation networks: 2
# Epochs: 50
# Device: cuda
#
# Epoch 005/50 | Train Loss: 2.5674 | Val Loss: 3.3567 | Link: 1.3927 | Contrast: 2.3379 | Recon: 0.0191 | Time: 266.70s

# %% [markdown]
# ## 5. View Results

# %%
# Load and display results
import json
from IPython.display import Image, display
import glob

# Choose which experiment to view
experiment_dir = 'experiments/phase1_full'  # or 'experiments/quick_test'

# Load results JSON
with open(f'{experiment_dir}/results_phase1.json', 'r') as f:
    results = json.load(f)

print("="*80)
print("EXPERIMENTAL RESULTS SUMMARY")
print("="*80)

# Training history
if 'training_history' in results:
    history = results['training_history']
    print(f"\nTraining:")
    print(f"  Final Train Loss: {history['train_loss'][-1]:.4f}")
    print(f"  Final Val Loss: {history['val_loss'][-1]:.4f}")
    print(f"  Best Val Loss: {min(history['val_loss']):.4f}")

# Baseline comparison
if 'baseline_comparison' in results:
    print("\nBaseline Comparison:")
    baseline_means = {k: sum(v)/len(v) for k, v in results['baseline_comparison'].items()}
    for method, mean in sorted(baseline_means.items(), key=lambda x: x[1], reverse=True):
        marker = " ★" if method == 'our_method' else ""
        print(f"  {method:<25}{marker} {mean:.4f}")

# Statistical tests
if 'statistical_tests' in results and 'baseline_comparison' in results['statistical_tests']:
    print("\nStatistical Significance:")
    comparisons = results['statistical_tests']['baseline_comparison']['comparisons']
    for method, stats in comparisons.items():
        if 'bonferroni_significant' in stats and stats['bonferroni_significant']:
            print(f"  ✓ {method}: Significantly different (p < Bonferroni α)")

# Ablation study
if 'ablation_study' in results:
    print("\nAblation Study - Component Importance:")
    ablation = results['ablation_study']
    components = [(k, v['performance_drop']) for k, v in ablation.items()
                  if k != 'full_model' and 'performance_drop' in v]
    components.sort(key=lambda x: x[1], reverse=True)
    for i, (component, drop) in enumerate(components[:5], 1):
        print(f"  {i}. {ablation[component]['name']}: {drop:.4f}")

# %%
# Display all generated figures
figures_dir = f'{experiment_dir}/figures'
figure_files = glob.glob(f'{figures_dir}/*.png')

print(f"\nGenerated {len(figure_files)} figures:")
for fig_path in sorted(figure_files):
    print(f"\n{'='*80}")
    print(f"Figure: {os.path.basename(fig_path)}")
    print(f"{'='*80}")
    display(Image(filename=fig_path))

# %% [markdown]
# ## 6. Download Results
#
# Download all results and figures

# %%
# Create zip file of all results
import shutil

experiment_dir = 'experiments/phase1_full'  # or your experiment directory
zip_filename = 'terrorist_network_results_phase1'

shutil.make_archive(zip_filename, 'zip', experiment_dir)
print(f"✓ Results packaged as {zip_filename}.zip")
print(f"  Download this file to access all results and figures")

# In Colab, this will create a downloadable file
from google.colab import files
files.download(f'{zip_filename}.zip')

# %% [markdown]
# ## 7. Advanced: Custom Analysis

# %%
# Example: Analyze specific components
import numpy as np
import matplotlib.pyplot as plt

# Load results
with open(f'{experiment_dir}/results_phase1.json', 'r') as f:
    results = json.load(f)

# Custom analysis example: Compare Q1 strategies in detail
if 'q1_critical_nodes' in results:
    q1_results = results['q1_critical_nodes']

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Box plot
    strategies = list(q1_results.keys())
    data = [[r['disruption'] for r in q1_results[s]] for s in strategies]

    axes[0].boxplot(data, labels=strategies)
    axes[0].set_ylabel('Disruption Score')
    axes[0].set_title('Q1 Strategy Distribution')
    axes[0].tick_params(axis='x', rotation=45)
    axes[0].grid(alpha=0.3)

    # Violin plot
    parts = axes[1].violinplot(data, positions=range(len(strategies)),
                                showmeans=True, showmedians=True)
    axes[1].set_xticks(range(len(strategies)))
    axes[1].set_xticklabels(strategies, rotation=45, ha='right')
    axes[1].set_ylabel('Disruption Score')
    axes[1].set_title('Q1 Strategy Distribution (Violin)')
    axes[1].grid(alpha=0.3)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 8. Export for Paper
#
# Generate publication-ready tables and figures

# %%
# Generate LaTeX table for baseline comparison
if 'baseline_comparison' in results:
    baseline_data = results['baseline_comparison']

    print("LaTeX Table for Paper:")
    print("\\begin{table}[h]")
    print("\\centering")
    print("\\caption{Baseline Method Comparison}")
    print("\\begin{tabular}{lcccc}")
    print("\\hline")
    print("Method & Mean & Std & Min & Max \\\\")
    print("\\hline")

    for method in sorted(baseline_data.keys(),
                        key=lambda x: np.mean(baseline_data[x]),
                        reverse=True):
        data = baseline_data[method]
        mean = np.mean(data)
        std = np.std(data)
        min_val = np.min(data)
        max_val = np.max(data)

        method_name = method.replace('_', '\\_')
        marker = "$^\\star$" if method == 'our_method' else ""

        print(f"{method_name}{marker} & {mean:.4f} & {std:.4f} & {min_val:.4f} & {max_val:.4f} \\\\")

    print("\\hline")
    print("\\end{tabular}")
    print("\\label{tab:baseline_comparison}")
    print("\\end{table}")

# %% [markdown]
# ---
#
# ## Summary
#
# This notebook implements Phase 1 enhancements:
#
# ### ✅ Completed:
# 1. **Self-Supervised Learning**: Temporal link prediction + contrastive learning + node reconstruction
# 2. **Baseline Comparisons**: 10+ methods (GCN, GAT, GraphSAGE, centrality measures, etc.)
# 3. **Statistical Tests**: t-tests, Wilcoxon, effect sizes, Bonferroni/Holm corrections
# 4. **Ablation Study**: Component importance quantification
#
# ### 📊 Outputs:
# - Trained model with self-supervised learning
# - Comprehensive baseline comparisons
# - Statistical significance results
# - Component contribution analysis
# - Publication-ready figures
# - LaTeX tables
